# %% [markdown]
# <a href="https://colab.research.google.com/github/sbsbsbsb1130-dot/python/blob/main/ex/04_%EC%9D%B8%EB%8D%B1%EC%8A%A4(%EC%97%B0%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Chapter 4. 인덱스

# %%
# 버전 안내
import pandas as pd
print(f'교재 권장 버전: Pandas 2.2.2')
print(f'현재 실행 버전: Pandas {pd.__version__}')
# Out:
# 교재 권장 버전: Pandas 2.2.2
# 현재 실행 버전: Pandas 2.2.2

# %% [markdown]
# ### 4.1 인덱싱과 슬라이싱
#
# 데이터에서 원하는 부분만 추출하는 기법
#
# ---
#
# 📌 인덱싱 (Indexing)
# - 특정 위치를 지정하여 데이터를 **개별적으로 선택**하는 기법
#
# 📌 슬라이싱 (Slicing)
# - 시작과 끝 범위를 설정하여 데이터를 **연속적인 구간으로 추출**하는 기법
#
# ---
#
# 판다스의 인덱싱/슬라이싱 방법 (3가지)
#
# 1. **대괄호 인덱서**
# 2. **`loc` 인덱서**
# 3. **`iloc` 인덱서**
#
# [표 4-2] 대괄호, loc, iloc 인덱서 비교
#
# | 구분 | 대괄호 인덱서 | loc 인덱서 | iloc 인덱서 |
# | :--- | :--- | :--- | :--- |
# | **대상** | 키(Key) | 키(Key) | 로케이션(Location) |
# | **행과 열을 동시에 인덱싱 및 슬라이싱** | 불가능 | 가능 | 가능 |
# | **행** | 슬라이싱만 가능 | 인덱싱, 슬라이싱 모두 가능 | 인덱싱, 슬라이싱 모두 가능 |
# | **열** | 인덱싱만 가능 | 인덱싱, 슬라이싱 모두 가능 | 인덱싱, 슬라이싱 모두 가능 |
# | **슬라이싱의 경계 조건** | 양쪽 경계 모두 포함 | 양쪽 경계 모두 포함 | 시작점만 포함하고 끝 지점은 불포함 |
#
# <br>

# %% [markdown]
# #### 4.1.1. 대괄호 인덱싱
#
# 📌 대괄호 인덱싱 (Bracket Indexing)
#
# - `[]` 안에 열 이름 → 시리즈/데이터 프레임 추출
# - 복수 열은 리스트로 입력
# - **장점**: 직관적, 간편함
# - **한계**:
#   - 열만 인덱싱 가능, 행은 슬라이싱만 가능
#   - `loc`/`iloc` 대비 활용 제한
# - **주요 활용**: 열 추출, 새로운 열 생성

# %%
# 코드 4-1. 실습을 위한 데이터 프레임 생성
import pandas as pd
data1 = [[84, 74, 86, 83, 60, 78],
         [69, 60, 91, 60, 91, 76],
         [88, 89, 80, 62, 62, 60],
         [72, 87, 90, 61, 98, 99],
         [90, 88, 64, 62, 83, 69]]
df = pd.DataFrame(data1, index=['A', 'B', 'C', 'D', 'E'],
                  columns=['국어','영어','수학','사회','과학','불어'])
# 원본인 df는 두고 df를 복제한 df1를 생성 실습한다.
df1 = df.copy()
df1
# Out:
#    국어  영어  수학  사회  과학  불어
# A  84  74  86  83  60  78
# B  69  60  91  60  91  76
# C  88  89  80  62  62  60
# D  72  87  90  61  98  99
# E  90  88  64  62  83  69

# %%
# 코드 4-2. 대괄호 인덱싱으로 국어 열을 시리즈로 추출
df1['국어']
# Out:
# A    84
# B    69
# C    88
# D    72
# E    90
# Name: 국어, dtype: int64

# %%
# 코드 4-3. 대괄호 인덱싱으로 복수의 열을 추출하기(영어, 과학 열)
df1[['영어','과학']]
# Out:
#    영어  과학
# A  74  60
# B  60  91
# C  89  62
# D  87  98
# E  88  83

# %%
# 코드 4-4. 동일한 열을 여러 번 인덱싱
# 과학, 영어, 과학 순으로 인덱싱
cols= ['과학','영어','과학']
df1[cols]
# Out:
#    과학  영어  과학
# A  60  74  60
# B  91  60  91
# C  62  89  62
# D  98  87  98
# E  83  88  83

# %%
# 코드 4-5. 대괄호 인덱싱으로 열의 순서 변경하기
# 과학, 영어, 수학, 사회, 불어, 국어 순으로 열의 순서 변경
cols = ['과학','영어','수학','사회','불어','국어']
df1[cols]
# Out:
#    과학  영어  수학  사회  불어  국어
# A  60  74  86  83  78  84
# B  91  60  91  60  76  69
# C  62  89  80  62  60  88
# D  98  87  90  61  99  72
# E  83  88  64  62  69  90

# %% [markdown]
# 대괄호에 존재하지 않는 열 이름을 입력해 출력하면 KeyError가 발생한다.
#
# ```python
# df1['체육']
# ```
# ```python
# KeyError: '체육'
# ```
# df1에는 체육 열이 없으므로 KeyError가 발생한다

# %% [markdown]
# #### 4.1.2. 대괄호 인덱싱으로 열 생성하기
#
# 📌 대괄호 인덱서: 새로운 열 생성과 수정
#
# - **존재하지 않는 열 인덱싱** → `KeyError` 발생
# - **존재하지 않는 열에 값 할당** → 새로운 열 생성
# - **존재하는 열에 값 할당** → 열 수정
# - **원리**: 딕셔너리와 동일한 방식
#
# [표 4-1] 대괄호 인덱싱과 열의 생성 및 수정하기
#
# | 구분 | 열 이름이 존재할 때 | 열 이름이 존재하지 않을 때 |
# | :--- | :--- | :--- |
# | **`df[열 이름]`** | 인덱싱 | KeyError 발생 |
# | **`df[열 이름] = 값`** | 열의 수정 | 열의 생성 |

# %%
# 코드 4-6. 대괄호 인덱싱으로 열 생성하기
# 체육 열을 새로 만들고 값은 모두 'pass'로 지정한 뒤 df1 출력

df=['체육'] = 'pass'
df
# Out:
#   File "/tmp/ipython-input-3246071055.py", line 4
#     df=['체육'] = 'pass'
#         ^
# SyntaxError: cannot assign to literal

# %%
# 코드 4-7. 서로 다른 값을 부여해 열 생성하기
# 도덕 열을 생성하고 값은 95, 87, 83, 91, 77을 순서대로 지정한 뒤 df1 출력
df1['도덕'] =[95, 87, 83, 91, 77]
df1
# Out:
#    국어  영어  수학  사회  과학  불어  도덕
# A  84  74  86  83  60  78  95
# B  69  60  91  60  91  76  87
# C  88  89  80  62  62  60  83
# D  72  87  90  61  98  99  91
# E  90  88  64  62  83  69  77

# %%
# 코드 4-8. 복수의 열 생성하기
# 미술 열과 음악 열을 동시에 생성하고 값은 모두 90점으로 지정
df1[['미술','음악']] = 90
df1
# Out:
#    국어  영어  수학  사회  과학  불어  도덕  미술  음악
# A  84  74  86  83  60  78  95  90  90
# B  69  60  91  60  91  76  87  90  90
# C  88  89  80  62  62  60  83  90  90
# D  72  87  90  61  98  99  91  90  90
# E  90  88  64  62  83  69  77  90  90

# %% [markdown]
# #### 4.1.3. 대괄호 인덱싱으로 열 수정하기

# %%
# 코드 4-9. 국어 열의 모든 값을 99점으로 수정

df1['국어'] = 99
df1
# Out:
#    국어  영어  수학  사회  과학  불어  도덕  미술  음악
# A  99  74  86  83  60  78  95  90  90
# B  99  60  91  60  91  76  87  90  90
# C  99  89  80  62  62  60  83  90  90
# D  99  87  90  61  98  99  91  90  90
# E  99  88  64  62  83  69  77  90  90

# %% [markdown]
# #### 4.1.4. 대괄호 슬라이싱
#
# 📌 대괄호 슬라이싱 (Bracket Slicing)
#
# - **특징**: 행을 슬라이싱 (열이 아니라는 점에 유의)
# - **한계**: 활용도가 낮아 거의 쓰이지 않음
# - **주요 활용**: 불리언 인덱싱으로 활용

# %%
# 코드 4-10. df에서 B 학생부터 D 학생까지 행을 추출하기(대괄호 슬라이싱)
df1['B':'D']
# Out:
#    국어  영어  수학  사회  과학  불어  도덕  미술  음악
# B  99  60  91  60  91  76  87  90  90
# C  99  89  80  62  62  60  83  90  90
# D  99  87  90  61  98  99  91  90  90

# %% [markdown]
# #### 4.1.5. 키 인덱싱과 슬라이싱(loc 인덱서)
#
# 📌 loc 인덱서
# - 행과 열의 **이름**(레이블)을 기준으로 인덱싱과 슬라이싱
# - 행과 열 모두 **인덱싱과 슬라이싱** 가능
# - 행과 열을 **동시에 지정** 가능

# %%
# 코드 4-11. df를 복제한 df2을 생성하고, A 학생의 국어 성적 추출하기
df2 = df.copy()
df2.loc['A','국어']
# Out:
# np.int64(84)

# %%
# 코드 4-12. loc 인덱서로 복수의 행과 열을 인덱싱(A, C, D / 국어, 수학)

df2.loc[['A','C','D'],['국어','수학']]
# Out:
#    국어  수학
# A  84  86
# C  88  80
# D  72  90

# %%
# 코드 4-13. B 행부터 D 행 / 영어부터 과학 성적까지 추출하기(loc 슬라이싱)
df2.loc['B':'D','영어':'과학']
# Out:
#    영어  수학  사회  과학
# B  60  91  60  91
# C  89  80  62  62
# D  87  90  61  98

# %%
# 코드 4-14. 시작점이 처음이거나 끝 지점이 마지막이면 생략 가능
# A에서 D / 수학에서 불어 모두 기입한 코드
df2.loc['A':'D','수학':'불어']
# 생략한 코드
df2.loc[:'D','수학':]
# Out:
#    수학  사회  과학  불어
# A  86  83  60  78
# B  91  60  91  76
# C  80  62  62  60
# D  90  61  98  99

# %%
# 코드 4-15. 모든 행을 가져온다면 행의 슬라이싱은 콜론(:)으로 대체 가능
# A에서 E / 수학에서 불어 모두 기입한 코드
df2.loc['A':'E','수학':'불어']
# 콜론으로 대체 가능
df2.loc[:,수학:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-327264260.py in <cell line: 0>()
#       3 df2.loc['A':'E','수학':'불어']
#       4 # 콜론으로 대체 가능
# ----> 5 df2.loc[:,수학:]
#
# NameError: name '수학' is not defined

# %%
# 코드 4-16. 모든 열을 가져온다면 열의 슬라이싱은 생략 가능
# A부터 D/ 모든 열 (열의 슬라이싱 콜론으로 대체 가능)
df2.loc['A':'D',:]
# A부터 D/ 모든 열 (열의 슬라이싱 생략 가능)
df2.loc['A':'D']
# Out:
#    국어  영어  수학  사회  과학  불어
# A  84  74  86  83  60  78
# B  69  60  91  60  91  76
# C  88  89  80  62  62  60
# D  72  87  90  61  98  99

# %% [markdown]
# 행을 전부 가져올 경우라도 행의 슬라이싱은 생략될 수 없다.
# 코드 4-15처럼 사용해야 한다.
#
# ```python
# df2.loc['수학':'과학'] # X
# df2.loc[:, '수학':'과학'] # O
# ```

# %%
# 코드 4-17. 인덱싱과 슬라이싱은 행과 열에 각각 적용 가능
# A부터 D / 과학과 수학

# %% [markdown]
# #### 4.1.6. loc 인덱서로 행과 열 생성하기
#
# 📌 loc 인덱서로 열과 행 생성
# - **열 생성 가능**: 일부 행에만 값 부여 시 사용 (일반 열 생성은 대괄호 인덱서)
# - **행 생성 가능**: 새로운 행 추가 가능 (빅데이터에서는 거의 사용하지 않음)

# %%
# 코드 4-18. B와 D에게만 80을 부여한 실험 열 생성하기
# df2에서 B와 D는 80, 나머지는 NaN인 실험 열 생성

# %%
# 코드 4-19. df2에서 A의 과학 점수를 70점으로 수정하기

# %%
# 코드 4-20. df2에서 전 과목 점수가 60인 F학생의 데이터 생성하기

# %% [markdown]
# #### 4.1.7. 로케이션 인덱싱과 슬라이싱(iloc 인덱서)
#
# 📌 iloc 인덱서
# - 행과 열의 **로케이션**(정수 인덱스, integer location index)을 기준으로 인덱싱과 슬라이싱
# - **기초 파이썬의 인덱싱/슬라이싱과 동일한 방식**으로 동작 (그림 4-10 참고)
# - 행과 열 모두 **인덱싱과 슬라이싱** 가능
# - 행과 열을 **동시에 지정** 가능
#
#
# [그림 4-10] 기초 파이썬의 인덱싱과 슬라이싱
#
# <img src=https://i.postimg.cc/DwVH85Hw/2-6.jpg, width=600>
#
# <img src=https://i.postimg.cc/4yNLkhjN/image.png, width=600>
#
# <br>

# %%
# 코드 4-21. df를 복제한 df3로 A 학생의 국어 점수 로케이션 인덱싱
df3 = df.copy()
# A 학생의 국어 점수 로케이션 인덱싱

# %%
# 코드 4-22. df3에서 A, C, D 학생의 국어와 수학 성적을 가져오기

# %%
# 코드 4-23. df3에서 행을 1:3, 열을 1:4로 슬라이싱

# %%
# 코드 4-24. df3에서 행은 B부터 D, 열은 영어부터 과학까지 로케이션 슬라이싱

# %%
# 코드 4-25. df3에서 행은 A부터 D, 열은 수학부터 불어까지 로케이션 슬라이싱

# %%
# 코드 4-26. df3의 첫 행을 시리즈로 추출하기

# %%
# 코드 4-27. df3의 마지막 행을 시리즈로 추출하기(음의 로케이션 활용)

# %%
# 코드 4-28. 인덱싱과 슬라이싱은 행과 열에 각각 적용 가능
# df3에서 B ~ D 슬라이싱 / 과학, 사회, 과학 인덱싱

# %% [markdown]
# #### 4.1.8. 인덱싱과 슬라이싱 정리
#
# [표 4-2] 대괄호, loc, iloc 인덱서 비교
#
# | 구분 | 대괄호 인덱서 | loc 인덱서 | iloc 인덱서 |
# | :--- | :--- | :--- | :--- |
# | **대상** | 키(Key) | 키(Key) | 로케이션(Location) |
# | **행과 열을 동시에 인덱싱 및 슬라이싱** | 불가능 | 가능 | 가능 |
# | **행** | 슬라이싱만 가능 | 인덱싱, 슬라이싱 모두 가능 | 인덱싱, 슬라이싱 모두 가능 |
# | **열** | 인덱싱만 가능 | 인덱싱, 슬라이싱 모두 가능 | 인덱싱, 슬라이싱 모두 가능 |
# | **슬라이싱의 경계 조건** | 양쪽 경계 모두 포함 | 양쪽 경계 모두 포함 | 시작점만 포함하고 끝 지점은 불포함 |
#
# <br>

# %% [markdown]
# ### 4.2. 데이터를 추출하는 함수들

# %% [markdown]
# #### 4.2.1. 행과 열 삭제하기(drop)
#
# <img src=https://i.postimg.cc/43LmhXkM/image.png, width=600>
#
# ⭐ 판다스 `drop`
#
# 데이터 프레임의 행이나 열을 삭제하는 함수
#
# <br>
#
# ⭐ `drop` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.drop(labels, axis=0, level=None))
# ```
#
# • **labels**: 삭제할 행 또는 열을 지정한다. 복수의 행이나 열을 지정하려면 리스트로 묶어서 입력한다.
#
# • **axis**: 행을 삭제할지 열을 삭제할지 지정한다. 기본값은 0이고 행을 삭제한다.
#
# • **level**: 멀티 인덱스일 때 삭제할 레벨을 지정한다.
#
# <br>

# %%
# 코드 4-29. drop 함수 실습 예제 코드
import pandas as pd
data1 = [[95, 65, 82], [84, 83, 76], [91, 88, 69], [91, 67, 90]]
idx = ['A', 'B', 'C', 'D']
cols = columns=['국어', '영어', '수학']
df = pd.DataFrame(data1, index=idx, columns=cols)
df
# Out:
#    국어  영어  수학
# A  95  65  82
# B  84  83  76
# C  91  88  69
# D  91  67  90

# %%
# 코드 4-30. df에서 영어 열 삭제

# %%
# 코드 4-31. df에서 영어와 수학 열 삭제

# %%
# 코드 4-32. drop 함수와 인덱싱 실습 예제 코드
data2 = {'이름': ['김판다', '강승주', '권보아', '임재범'],
         '국어점수': [88, 81, 89, 79], '영어점수': [68, 82, 84, 80],
         '수학점수': [75, 80, 84, 89], '과학점수': [75.5, 62, 82, 89],
         '성별': ['남', '여', '여', '남'], '반': ['A', 'B', 'A', 'B'],
         '전형': ['수시', '수시', '정시', '정시']}
df1 = pd.DataFrame(data2)
df1
# Out:
#     이름  국어점수  영어점수  수학점수  과학점수 성별  반  전형
# 0  김판다    88    68    75  75.5  남  A  수시
# 1  강승주    81    82    80  62.0  여  B  수시
# 2  권보아    89    84    84  82.0  여  A  정시
# 3  임재범    79    80    89  89.0  남  B  정시

# %%
# 코드 4-33. df1에서 이름과 성별 열을 제외하고 모두 인덱싱

# %%
# 코드 4-34. df1에서 이름과 성별 열을 삭제

# %%
# 코드 4-35. 인덱싱과 drop 함수의 조합도 가능
# iloc 인덱서로 국어점수 열부터 반 열까지 슬라이싱 후에 과학점수 열 삭제하기

# %% [markdown]
# 📌 판다스에서 키와 로케이션을 적용하는 방법
#
# 1. **하나의 함수/기법에서 모두 적용 가능할 때**
#    - 예: `read_excel` 함수의 매개변수 `sheet_name`
#    - 키와 로케이션 모두 입력 가능 → **간편한 방법 선택**
#
# 2. **서로 다른 함수/기법으로 각각 적용할 때**
#    - 예: `loc` 인덱서와 `iloc` 인덱서
#    - `loc`: **키**(레이블)로 인덱싱
#    - `iloc`: **로케이션**(정수 위치)로 인덱싱
#    - 상황에 따라 편한 쪽을 선택해 사용
#
# 3. **키만 적용 가능한 경우**
#    - 예: `drop` 함수
#    - 삭제할 **키만 입력 가능** → 로케이션 직접 사용 불가
#    - 하지만 `df.columns`를 활용하면 로케이션으로 열 이름 반환 가능
#    - 예시:
#      ```python
#      df.drop(df.columns[0], axis=1)  # 첫 번째 열 삭제
#      ```

# %% [markdown]
# #### 4.2.2. 열 이름으로 필터링(filter)
#
# <img src=https://i.postimg.cc/NFyT05yF/image.png, width=600>
#
# ⭐ 판다스 `filter`
#
# 열 이름으로 데이터 프레임을 필터링하는 함수
#
# <br>
#
# ⭐ `filter` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.filter(items=None, like=None, regex=None)
# ```
#
# - **items**: 정확하게 일치하는 문자열을 기준으로 필터링할 때 사용한다.
# - **like**: 포함하는 문자열을 기준으로 필터링할 때 사용한다.
# <br>

# %%
# 코드 4-36. filter 함수 실습 예제 코드
data1 = [[81, 80, 65, 62], [62, 88, 87, 78],
         [73, 71, 87, 66], [61, 63, 75, 78]]
df = pd.DataFrame(data1, columns=['국어', '영어', '수학', '고전국어'])
df
# Out:
#    국어  영어  수학  고전국어
# 0  81  80  65    62
# 1  62  88  87    78
# 2  73  71  87    66
# 3  61  63  75    78

# %%
# 코드 4-37. df에서 열 이름에 국어를 포함하는 열만 필터링

# %%
# 코드 4-38. 코드 4-32의 df1에서 열 이름에 점수가 포함된 열만 필터링하기

# %% [markdown]
# #### 4.2.3. 자료형으로 열 선택하기(select_dtypes)
#
# <img src=https://i.postimg.cc/Y98KSC5V/image.png, width=600>
#
# ⭐ 판다스 `select_dtypes`
#
# 열의 자료형에 기반하여 데이터 프레임을 필터링하는 함수
#
# <br>
#
# ⭐ `select_dtypes` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.select_dtypes(include=None, exclude=None)
# ```
#
# - **include**: 포함할 자료형을 지정한다. 단일 값 또는 리스트 형태로 지정이 가능하다.
#
#
# - **exclude**: 제외할 자료형을 지정한다. 단일 값 또는 리스트 형태로 지정이 가능하다.
#
# <br>

# %%
# 코드 4-39. select_dtypes 함수 실습 예제 코드
data1 = {'이름': ['김판다', '강승주', '권보아', '임재범'],
         '국어': [81, 80, 65, 62], '영어': [62, 88.5, 87, 78],
         '성별': ['남', '여', '여', '남']}
df = pd.DataFrame(data1)
df
# Out:
#     이름  국어    영어 성별
# 0  김판다  81  62.0  남
# 1  강승주  80  88.5  여
# 2  권보아  65  87.0  여
# 3  임재범  62  78.0  남

# %%
# 코드 4-40. df의 자료형 확인하기
df.dtypes
# Out:
# 이름     object
# 국어      int64
# 영어    float64
# 성별     object
# dtype: object

# %%
# 코드 4-41. 정수인 열과 실수인 열만 추출
# 자료형이 정수인 국어 열만 추출

# 자료형이 실수인 영어 열만 추출

# %%
# 코드 4-42. df에서 정수와 실수 등 수치형 데이터인 열만 추출하기

# %%
# 코드 4-43. df에서 실수 자료형인 열 제외하기

# %% [markdown]
# #### 4.2.4. 판다스의 함수와 원본 변경하기
#
# 📌 판다스 함수와 원본 변경
# - 대부분 함수는 **원본을 변경하지 않음** → 새로운 데이터프레임 반환
# - 원본을 변경하려면 **등호(=)로 재지정** 필요 (배정)
# - 원본 유지 덕분에 **병렬 처리·체인 메서드** 활용 가능
# - **예외**: `insert`, `update` 등은 원본을 즉시 변경

# %%
# 코드 4-44. 코드 4-42의 함수 적용 결과로 원본 df를 변경하기

# %% [markdown]
# ### 엑셀 예제 1. 타이타닉 침몰 사고 승객 데이터 인덱싱과 슬라이싱
#
# <img src=https://i.postimg.cc/rwFLvW7c/image.png, width=600>
#
# - PassengerId: 승객의 고유 ID
# - Survived: 생존 여부, 0은 사망, 1은 생존을 의미
# - Pclass: 객실 등급, 1등석, 2등석, 3등석으로 구분
# - Name: 승객의 이름
# - Gender: 승객의 성별. male, female로 구분
# - Age: 승객의 나이
# - SibSp: Siblings/Spouses의 약자. 승객이 동반한 형제나 배우자의 수
# - Parch: Parents/Children의 약자. 승객이 여객선에 동반한 부모, 자녀의 수
# - Ticket: 승객이 구매한 티켓 번호
# - Fare: 승객이 티켓을 구매할 때 지불한 요금
# - Cabin: 승객이 탑승한 객실 번호
# - Embarked: 승객이 탑승한 항구. 사우샘프턴(S), 셸부르크(C), 퀸스타운(Q)

# %%
# 코드 4-45. 타이타닉 엑셀파일에서 데이터 프레임 불러오기
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력 코드
url1 = 'https://github.com/panda-kim/book1/blob/main/05titanic.xlsx?raw=true'
df_titanic = pd.read_excel(url1)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ..                                                 ...     ...   ...    ...
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 코드 4-46. df_titanic의 컬럼즈 확인하기

# %%
# 코드 4-47. 생존여부, 객실등급, 성별, 나이, 요금 열만 가져오기
cols = ['Survived', 'Pclass', 'Gender', 'Age', 'Fare']

# %%
# 코드 4-48. 수치형 데이터의 상위 100행만 가져오기

# %% [markdown]
# ### 4.3. 인덱스와 컬럼즈를 다루는 함수들

# %% [markdown]
# #### 4.3.1. 인덱스 설정하기(set_index)
#
# <img src=https://i.postimg.cc/jSpr350v/image.png, width=600>
#
# ⭐ 판다스 `set_index`
#
# 데이터 프레임의 인덱스를 설정하는 함수 (컬럼즈를 설정할 수는 없다.)
#
# <br>
#
# ⭐ `set_index` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.set_index(keys, axis=0)
# ```
# - **keys**: 인덱스로 설정될 열을 지정한다.
#
# <br>

# %%
# 코드 4-49. 실습 예제 코드
import pandas as pd
data = [['송중기', 70, 'A'], ['강승주', 80, 'A'],
        ['김판다', 93, 'B'], ['이예준', 92, 'B']]
df = pd.DataFrame(data, columns=['이름', '점수', '반'])
df1 = df.set_index('이름')
df2 = df.copy() # df를 복제한 df2
df
# Out:
#     이름  점수  반
# 0  송중기  70  A
# 1  강승주  80  A
# 2  김판다  93  B
# 3  이예준  92  B

# %%
# 코드 4-50. df의 이름 열을 인덱스로 설정하기

# %%
# 코드 4-51. 복수의 열을 인덱스로 설정하기
# df에서 반과 이름 열을 인덱스로 설정

# %% [markdown]
# #### 4.3.2. 인덱스 리셋하기(reset_index)
#
# <img src=https://i.postimg.cc/jSmJ8zSc/image.png, width=600>
#
# ⭐ 판다스 `reset_index`
#
# 인덱스에서 데이터를 제거하는 함수 (컬럼즈를 대상으로는 사용할 수 없다.)
#
# 인덱스에서만 데이터를 제거해 데이터 프레임의 열이 되거나, 데이터를 완전히 삭제할 수 있다. 인덱스가 모두 제거되면 새
# 로운 RangeIndex가 생성된다.
#
# <br>
#
# ⭐ `reset_index` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.reset_index(level=None, drop=False)
# ```
#
# - **level**: 멀티 인덱스에서 리셋할 인덱스의 레벨을 지정한다.
# - **drop**: 인덱스에서만 제거할지 완전히 데이터를 삭제할지 지정한다. 기본값은 인덱스의 데이터가 열이 된다.
#
# <br>

# %%
# 코드 4-52. 코드 4-49의 df1의 인덱스를 일반 열로 변환하기

# %%
# 코드 4-53. 인덱스의 데이터를 완전히 삭제하기
# df1의 인덱스를 완전히 삭제하기

# %% [markdown]
# #### 4.3.3. 인덱스와 컬럼즈 변경하기(배정)
#
# 📌 인덱스·컬럼즈 변경 (배정 방식)
# - `index` / `columns` 속성에 새 배열을 **등호(=)로 배정** → 원본 즉시 변경
# - 배열 길이는 기존과 반드시 동일해야 함
# - 주로 **컬럼즈 이름 변경**에 활용

# %%
# 코드 4-54. 컬럼즈를 배정 방식으로 변경하기
# df2의 컬럼즈를 배정 방식으로 'Name', 'Score', 'Class' 순서로 변경

# %% [markdown]
# #### 4.3.4. 인덱스와 컬럼즈 변경하기(set_axis)
#
# <img src=https://i.postimg.cc/x8NKjt8b/image.png, width=600>
#
#
# ⭐ 판다스 `set_axis`
#
# 인덱스나 컬럼즈를 변경하는 함수. 인덱스나 컬럼즈를 배정해 변경하는 방식과 결과는 동일하지만 원본을 변경하
# 지 않는다.
#
# <br>
#
# ⭐ `set_axis` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.set_axis(labels, axis=0)
# ```
#
# - **labels**: 새로운 인덱스나 컬럼즈를 지정한다.
# - **axis**: 인덱스를 변경할지 컬럼즈를 변경할지 지정한다.
#
# <br>

# %%
# 코드 4-55. df의 컬럼즈를 set_axis 함수로 변경하기
# df의 컬럼즈를 set_axis 함수로 'Name', 'Score', 'Class' 순서로 변경

# %% [markdown]
# #### 4.3.5. 열 이름 변경하기(rename)
#
# <img src=https://i.postimg.cc/tghRbP9g/image.png, width=600>
#
# ⭐ 판다스 `rename`
#
# 행 이름이나 열 이름을 변경하는 함수. 주로 열 이름을 변경할 때 사용한다.
#
# <br>
#
#
# ⭐ `rename` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.rename(mapper=None, axis=0, level=None)
# ```
# - **mapper**: 이전 이름과 새롭게 부여할 이름을 매퍼(mapper)로 입력한다.
# - **axis**: 행 이름을 변경할지 열 이름을 변경할지 지정한다.
#
# - **level**: 멀티 인덱스일 때 적용할 레벨을 지정한다.
#
# <br>

# %%
# 코드 4-56. df에서 점수 열의 이름을 성적으로 변경하기

# %%
# 코드 4-57. df에서 점수 열을 성적으로, 반 열을 소속으로 변경하기

# %% [markdown]
# #### 4.3.6. 매핑과 매퍼
#
# <img src=https://i.postimg.cc/wvmGZczr/image.png, width=600>

# %% [markdown]
# #### 4.3.7. 데이터 재배열하기(reindex)
#
# <img src=https://i.postimg.cc/Pf8CVLwL/image.png, width=600>
#
# ⭐ 판다스 `reindex`
#
# 인덱스나 컬럼즈의 순서를 재배열해서 데이터를 재배열하는 함수
#
# <br>
#
# ⭐ `reindex` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.reindex(labels, axis=0)
# ```
#
# - **labels**: 재배열할 새로운 순서를 입력한다.
# - **axis**: 인덱스를 재배열할지 컬럼즈를 재배열할지 지정한다.
#
# <br>

# %%
# 코드 4-58. df의 열을 이름, 반, 성별 순으로 재배열

# %% [markdown]
# #### 4.3.8. 인덱스명 변경하기(rename_axis)
#
# <img src=https://i.postimg.cc/j2GN9PsQ/image.png, width=600>
#
# ⭐ 판다스 `rename_axis`
#
# 인덱스명을 변경하는 함수
#
# <br>
#
# ⭐ `rename_axis` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.rename_axis(mapper=None, axis=0)
# ```
#
# - **mapper**: 변경할 인덱스명을 입력한다.
# - **axis**: 인덱스의 인덱스명을 변경할지 컬럼즈의 인덱스명을 변경할지 지정한다.
#
# <br>

# %%
# 코드 4-59. df1에서 인덱스의 인덱스명 제거하기

# %% [markdown]
# #### 4.3.9. 인덱스 클래스를 리스트로 변환하기(tolist)
#
# 📌 인덱스·컬럼즈를 리스트로 변환하기
# - 기초 파이썬 숙련자는 인덱스 클래스를 리스트로 변환해 다룬 뒤 다시 **배정**하기도 함
# - `tolist` 함수 → 인덱스/컬럼즈를 **리스트로 변환**
# - 데이터 프레임이 아닌 **인덱스 클래스에 적용**

# %%
# 코드 4-60. df의 컬럼즈를 리스트로 변환하기

# %% [markdown]
# ### 4.4. 멀티 인덱스 소개
#
# 📌 멀티 인덱스
# - **복수 인덱스/컬럼즈** → 멀티 인덱스
# - **구조**: 튜플로 구성
# - 핵심 함수: `stack`, `unstack`

# %% [markdown]
# #### 4.4.1. 멀티 인덱스와 레벨
#
# <img src=https://i.postimg.cc/HnjR3Dx2/image.png, width=600>

# %%
# 코드 4-61. 멀티 인덱스 실습 예제 코드
import pandas as pd
data1 = {('국어', '남'): {'1반': 10, '2반': 20},
         ('국어', '여'): {'1반': 30, '2반': 40},
         ('영어', '남'): {'1반': 15, '2반': 25},
         ('영어', '여'): {'1반': 35, '2반': 45}}
df = pd.DataFrame(data1)
df
# Out:
#     국어      영어
#      남   여   남   여
# 1반  10  30  15  35
# 2반  20  40  25  45

# %%
# 코드 4-62. df의 컬럼즈를 확인해, 멀티 인덱스를 확인

# %%
# 코드 4-63. df의 멀티 인덱스를 단일 인덱스로 변경하기
# set_axis 함수로 df에 단일 인덱스 부여 ('국어_남', '국어_여', '영어_남', '영어_여')

# %% [markdown]
# #### 4.4.2. 멀티 인덱스의 구조 변경하기(stack, unstack)
#
# <img src=https://i.postimg.cc/2yKJtz9P/image.png, width=600>
#
# ⭐ 판다스 `stack`과 `unstack`
#
# 인덱스나 컬럼즈의 데이터를 상호 이동해 데이터의 구조를 변경하는 함수. `stack`은 컬럼즈를 인덱스로 이동시키
# 고 `unstack`은 인덱스를 컬럼즈로 이동시킨다.
#
# <br>
#
# ⭐ `stack` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.stack(level=-1, dropna=True)
# ```
# - **level**: 인덱스로 이동할 컬럼즈의 레벨을 지정한다.
# - **dropna**: `stack` 함수를 적용한 후에 값이 NaN인 행이 생성될 수 있는데 값이 NaN인 행을 생성할지 삭제할지
# 지정한다.
# - **future_stack**: Pandas 3.0부터 표준이 될 신규 구현 방식을 활성화하는 옵션이다. `True` 설정 시 차기 버전과의 호환성이 확보되지만, 이 경우 `dropna`와 `sort` 인자는 사용할 수 없으므로 주의해야 한다. (Pandas 2.1+ 도입)
#
# <br>
#
# ⭐ `unstack` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.unstack(labels, axis=0, level=None)
# ```
#
# - **level**: 컬럼즈로 이동할 인덱스의 레벨을 지정한다.
# - **fill_value**: NaN을 대체할 값을 지정한다.
#
# <br>

# %%
# 코드 4-64. stack 함수로 df의 구조 변경하기(변경된 코드)

# %% [markdown]
# 🚨  Pandas 2.1+ `stack` 변경 사항
#
# - 기존 `df.stack()` → **FutureWarning** 발생 (향후 삭제 예정)
# - 권장 방식: `df.stack(future_stack=True)` 명시적 사용
# - 최신 버전에서는 **future_stack 옵션 필수**
